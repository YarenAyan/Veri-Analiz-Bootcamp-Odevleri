# %% [markdown]
# # Titanic Veri Seti Analizi
#
# Bu çalışmada, Kaggle'da yer alan Titanic veri seti kullanılarak çeşitli analizler gerçekleştirilmiştir. Titanic yolcularının hayatta kalıp kalmamaları, yaş, cinsiyet, bilet sınıfı ve ücret gibi demografik ve seyahat bilgileri üzerinden incelenmiştir. Aşağıdaki yer alan sorulara odaklanarak veriler analiz edilmiş ve altında Python kodları ile çözümler verilmiştir.
#
# Veri seti hakkında detaylı bilgiye aşağıdaki linkten ulaşabilirsiniz:
# 🔗 https://www.kaggle.com/c/titanic/data

# %%
import pandas as pd
df_titanic = pd.read_csv("Titanic_dataset.csv")

# %% [markdown]
# ### Veri Setinin Genel Bilgileri

# %%
df_titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %% [markdown]
# ### Veri Setinin İlk 10 Satırı

# %%
df_titanic.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# 6                            McCarthy, Mr. Timothy J    male  54.0      0
# 7                     Palsson, Master. Gosta Leonard    male   2.0      3
# 8  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S
# 5      0            330877   8.4583   NaN        Q
# 6      0             17463  51.8625   E46        S
# 7      1            349909  21.0750   NaN        S
# 8      2            347742  11.1333   NaN        S
# 9      0            237736  30.0708   NaN        C

# %% [markdown]
# ### Sayısal Değişkenlerin İstatistiksel Özeti

# %%
df_titanic.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %% [markdown]
# **1. Kazada ölenlerin yaş ortalamasını bulunuz.**

# %%
df_titanic[df_titanic['Survived'] == 0]['Age'].mean()
# Out:
# 30.62617924528302

# %% [markdown]
# **2. Kazada ölenlerin bilet fiyatlarının ortalamasını ve medyanını bulunuz.**

# %%
dead_fare = df_titanic[df_titanic['Survived'] == 0]['Fare']
dead_fare.mean(), dead_fare.median()
# Out:
# (22.117886885245877, 10.5)

# %% [markdown]
# **3. Kazada ölen erkeklerin yaş ortalamasını bulunuz.**

# %%
df_titanic[(df_titanic['Survived'] == 0) & (df_titanic['Sex'] == 'male')]['Age'].mean()
# Out:
# 31.618055555555557

# %% [markdown]
# **4. Kazada ölen kadınların yaş ortalamasını bulunuz.**

# %%
df_titanic[(df_titanic['Survived'] == 0) & (df_titanic['Sex'] == 'female')]['Age'].mean()
# Out:
# 25.046875

# %% [markdown]
# **5. Kazadan kurtulanların yaş ortalamasını bulunuz.**

# %%
df_titanic[df_titanic['Survived'] == 1]['Age'].mean()
# Out:
# 28.343689655172415

# %% [markdown]
# **6. Kazadan kurtulanların bilet fiyatlarının ortalamasını bulunuz.**

# %%
df_titanic[df_titanic['Survived'] == 1]['Fare'].mean()
# Out:
# 48.39540760233917

# %% [markdown]
# **7. Kazadan kurtulan toplam kişi sayısını bulunuz.**

# %%
len(df_titanic[df_titanic['Survived'] == 1])
# Out:
# 342

# %% [markdown]
# **8. 10 yaşından küçüklerin bilet fiyatlarının medyan değerini bulunuz.**

# %%
df_titanic[df_titanic['Age'] < 10]['Fare'].median()
# Out:
# 27.0

# %% [markdown]
# **9. 1., 2. ve 3. sınıf bilet fiyatlarının ortalama ve medyanlarını karşılaştırınız.**

# %%
df_titanic.groupby('Pclass')['Fare'].agg(['mean', 'median'])
# Out:
#              mean   median
# Pclass
# 1       84.154687  60.2875
# 2       20.662183  14.2500
# 3       13.675550   8.0500

# %% [markdown]
# **10. Kazada ölen kadınların oranı ile erkeklerin oranını karşılaştırınız.**

# %%
total_men = df_titanic[df_titanic['Sex'] == 'male']
total_women = df_titanic[df_titanic['Sex'] == 'female']

dead_men_ratio = len(total_men[total_men['Survived'] == 0]) / len(total_men)
dead_women_ratio = len(total_women[total_women['Survived'] == 0]) / len(total_women)

dead_men_ratio, dead_women_ratio
# Out:
# (0.8110918544194108, 0.25796178343949044)
